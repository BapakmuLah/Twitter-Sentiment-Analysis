# %% [markdown]
# # Import Library

# %%
import nltk
import random
import os
import numpy as np
from nltk.corpus import twitter_samples
from matplotlib import pyplot as plt
from nltk.tokenize import TweetTokenizer
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %% [markdown]
# # Load Dataset

# %%
# DOWNLOAD DATASET

nltk.download('twitter_samples', download_dir= os.getcwd())
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     c:\Tensorflow\NLP\NLP Twitter...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
import os

# Print the contents of the directory
print(os.listdir(r'C:\Tensorflow\NLP\NLP Twitter\corpora\twitter_samples'))
# Out:
# ['negative_tweets.json', 'positive_tweets.json', 'README.md', 'README.txt', 'tweets.20150430-223406.json']

# %%
# LOAD DATASET 

current_directory = os.getcwd()

# MOVE NLTK TO THAT PATH
nltk.data.path.append(r'C:\Tensorflow\NLP\NLP Twitter')

all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

print(f'Positive Tweets has {len(all_positive_tweets)} samples')
print(f'Negative Tweets has {len(all_negative_tweets)} samples')
# Out:
# Positive Tweets has 5000 samples
# Negative Tweets has 5000 samples

# %% [markdown]
# ###  Display 10 Positive Tweets

# %%
# DISPLAY 10 SAMPLES FROM POSITIVE TWEETS

for i in range(0,10):
    print(f'Tweet {i+1} : {all_positive_tweets[i]}')
# Out:
# Tweet 1 : #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
# Tweet 2 : @Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!
# Tweet 3 : @DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!
# Tweet 4 : @97sides CONGRATS :)
# Tweet 5 : yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days
# Tweet 6 : @BhaktisBanter @PallaviRuhail This one is irresistible :)
# #FlipkartFashionFriday http://t.co/EbZ0L2VENM
# Tweet 7 : We don't like to keep our lovely customers waiting for long! We hope you enjoy! Happy Friday! - LWWF :) https://t.co/smyYriipxI
# Tweet 8 : @Impatientraider On second thought, there’s just not enough time for a DD :) But new shorts entering system. Sheep must be buying.
# Tweet 9 : Jgh , but we have to go to Bayan :D bye
# Tweet 10 : As an act of mischievousness, am calling the ETL layer of our in-house warehousing app Katamari.
#
# Well… as the name implies :p.

# %% [markdown]
# ### Display 10 Negative Tweets

# %%
# DISPLAY 10 SAMPLES FROM NEGATIVE TWEETS

i = 0

for tweet in all_negative_tweets:
    if i == 10:
        break

    print(f'Tweet {i+1} : {tweet}')
    i += 1
# Out:
# Tweet 1 : hopeless for tmr :(
# Tweet 2 : Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(
# Tweet 3 : @Hegelbon That heart sliding into the waste basket. :(
# Tweet 4 : “@ketchBurning: I hate Japanese call him "bani" :( :(”
#
# Me too
# Tweet 5 : Dang starting next week I have "work" :(
# Tweet 6 : oh god, my babies' faces :( https://t.co/9fcwGvaki0
# Tweet 7 : @RileyMcDonough make me smile :((
# Tweet 8 : @f0ggstar @stuartthull work neighbour on motors. Asked why and he said hates the updates on search :( http://t.co/XvmTUikWln
# Tweet 9 : why?:("@tahuodyy: sialan:( https://t.co/Hv1i0xcrL2"
# Tweet 10 : Athabasca glacier was there in #1948 :-( #athabasca #glacier #jasper #jaspernationalpark #alberta #explorealberta #… http://t.co/dZZdqmf7Cz

# %% [markdown]
# # Preprocess Raw Text

# %% [markdown]
# ## Splitting Data

# %%
# SPLIT DATA INTO TRAIN AND TEST

train_data = np.concatenate((all_positive_tweets[:4000], all_negative_tweets[:4000]), axis=0)
test_data  = np.concatenate((all_positive_tweets[4000:5000], all_negative_tweets[4000:5000]), axis=0)

len(train_data) , len(test_data) , train_data[:2] , test_data[:2]
# Out:
# (8000,
#  2000,
#  array(['#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)',
#         '@Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!'],
#        dtype='<U152'),
#  array(['Bro:U wan cut hair anot,ur hair long Liao bo\nMe:since ord liao,take it easy lor treat as save $ leave it longer :)\nBro:LOL Sibei xialan',
#         "@heyclaireee is back! thnx God!!! i'm so happy :)"], dtype='<U146'))

# %% [markdown]
# ## Create a Label for every Tweet

# %%
# CREATE LABEL . IF THEY POSITIVE TWEET, GIVE THEM 1  .   AND IF THEY NEGATIVE TWEET , GIVE THEM 0

train_positive = all_positive_tweets[:4000]
train_negative = all_negative_tweets[:4000]

test_positive = all_positive_tweets[4000:5000]
test_negative = all_negative_tweets[4000:5000]

#            FILL VALUE 1        shape=(4000,1)          FILL VALUE 0  shape=(4000,1)
train_label = np.append(np.ones( shape=( len(train_positive),1) ), np.zeros( shape=( len(train_negative),1) ), axis=0)

#           FILL VALUE 1         shape=(1000,1)          FILL VALUE 0  shape=(1000,1)
test_label  = np.append(np.ones( shape=( len(test_positive),1) ) , np.zeros( shape=( len(test_negative),1) ), axis=0)


# DEBUGGING
len(train_label) , len(test_label) , train_label , test_label
# Out:
# (8000,
#  2000,
#  array([[1.],
#         [1.],
#         [1.],
#         ...,
#         [0.],
#         [0.],
#         [0.]]),
#  array([[1.],
#         [1.],
#         [1.],
#         ...,
#         [0.],
#         [0.],
#         [0.]]))

# %%
# VISUALIZE DATASET TWEETS USING DATAFRAME 

import pandas as pd

data = {
    'Tweets': train_data,
    'Label' : train_label.reshape(-1)
}

df = pd.DataFrame(data)

df
# Out:
#                                                  Tweets  Label
# 0     #FollowFriday @France_Inte @PKuchly57 @Milipol...    1.0
# 1     @Lamb2ja Hey James! How odd :/ Please call our...    1.0
# 2     @DespiteOfficial we had a listen last night :)...    1.0
# 3                                  @97sides CONGRATS :)    1.0
# 4     yeaaaah yippppy!!!  my accnt verified rqst has...    1.0
# ...                                                 ...    ...
# 7995                   Amelia didnt stalk my twitter :(    0.0
# 7996                    oh, i missed the broadcast. : (    0.0
# 7997  i really can't stream on melon i feel useless :-(    0.0
# 7998   I need to stop looking at old soccer pictures :(    0.0
# 7999  Got an interview for the job that I want but t...    0.0
#
# [8000 rows x 2 columns]

# %% [markdown]
# ## Text Cleaning

# %%
# CLEANING TWEETS

import re  # USING REGEX TO CLEANING TEXT

def TextCleaning(tweet):

    if not isinstance(tweet, str):
        raise TypeError(f"Expected string, got {type(tweet)}")
    
    # REMOVE HYPERLINK
    cleaning_tweets = re.sub(pattern=r'https?://[^\n\r\s]+', repl= '', string= tweet)

    # REMOVE USENAME
    cleaning_tweets = re.sub(pattern=r'@\w+', repl='', string= cleaning_tweets)

    # REMOVE HASHTAGS
    cleaning_tweets = re.sub(pattern=r'#', repl='', string= cleaning_tweets)

    return cleaning_tweets

# %% [markdown]
# #### Display Function

# %%
# DISPLAY TWEETS AFTER CLEANED

# BEFORE CLEANING
print('Before Clean :')
for tweet in train_data[:5]:
    print(tweet)

i = 0
cleaned_tweets = []

print('\nAfter Clean :')
for tweet in train_data:
    clean_tweet = TextCleaning(tweet)

    # JUST PRINT THE FIRST 5 TWEET
    if i < 5:
        print(clean_tweet)
    i += 1
    cleaned_tweets.append(clean_tweet)
# Out:
# Before Clean :
# #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
# @Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!
# @DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!
# @97sides CONGRATS :)
# yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days
#
# After Clean :
# FollowFriday    for being top engaged members in my community this week :)
#  Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!
#  we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!
#  CONGRATS :)
# yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days

# %% [markdown]
# ## Tokenization

# %%
# TRANSFORM TWEET INTO EACH TOKEN

def Tokenization(tweet):

    # DECLARE TOKENIZER
    tokenizer = TweetTokenizer(preserve_case=False, reduce_len=True, strip_handles=True)

    # TRANSFORM TO EVERY TWEETS/STRINGS
    tweet_token= tokenizer.tokenize(tweet)

    return tweet_token

# %%
# DISPLAY TWEET AFTER TOKENIZATION

print('Tweet After Tokenization :')

i = 0
tweet_tokens = []

for tweet in cleaned_tweets:
    tweet_token = Tokenization(tweet)

    # JUST PRINT THE FIRST 5 TWEET
    if i < 5:
        print(tweet_token)

    i += 1
    tweet_tokens.append(tweet_token)
# Out:
# Tweet After Tokenization :
# ['followfriday', 'for', 'being', 'top', 'engaged', 'members', 'in', 'my', 'community', 'this', 'week', ':)']
# ['hey', 'james', '!', 'how', 'odd', ':/', 'please', 'call', 'our', 'contact', 'centre', 'on', '02392441234', 'and', 'we', 'will', 'be', 'able', 'to', 'assist', 'you', ':)', 'many', 'thanks', '!']
# ['we', 'had', 'a', 'listen', 'last', 'night', ':)', 'as', 'you', 'bleed', 'is', 'an', 'amazing', 'track', '.', 'when', 'are', 'you', 'in', 'scotland', '?', '!']
# ['congrats', ':)']
# ['yeaaah', 'yipppy', '!', '!', '!', 'my', 'accnt', 'verified', 'rqst', 'has', 'succeed', 'got', 'a', 'blue', 'tick', 'mark', 'on', 'my', 'fb', 'profile', ':)', 'in', '15', 'days']

# %% [markdown]
# ## Remove Stop Words and Punctuation

# %%
# GET STOPWORDS AND PUNCTUATION

# DOWNLOAD STOPWORDS
nltk.download(info_or_id='stopwords')

stopwords_english = stopwords.words('english')

print(f'size stopwords : {len(stopwords_english)}')
print(f'Stopwords : {stopwords_english[:20]}')  # DISPLAY 20 STOPWORDS

print(f'Punctuation : {string.punctuation}\n')
# Out:
# size stopwords : 179
# Stopwords : ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his']
# Punctuation : !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aliff\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# REMOVE STOPWORDS AND PUNCTUATION

def remove_StopWords(tweet):

    cleaned_token = []

    # ITERATE EVERY TOKEN IN A TWEET         
    for word in tweet:   

        # IF TOKEN DOESNT CONTAIN STOPWORDS AND PUNCTUATION
        if (word not in stopwords_english and word not in string.punctuation):
            cleaned_token.append(word) # PUSH THAT TOKEN
                

    return cleaned_token

# %%
# DISPLAY TWEET AFTER REMOVED STOP WORDS

i = 0
cleaned_tweets = []

print('After Removed Stopwords and Punctuation :')
for tweet in tweet_tokens:
    tweet_clean = remove_StopWords(tweet)

    # JUST PRINT THE FIRST 5 TWEET
    if i < 5:
        print(tweet_clean)

    i += 1
    cleaned_tweets.append(tweet_clean)
# Out:
# After Removed Stopwords and Punctuation :
# ['followfriday', 'top', 'engaged', 'members', 'community', 'week', ':)']
# ['hey', 'james', 'odd', ':/', 'please', 'call', 'contact', 'centre', '02392441234', 'able', 'assist', ':)', 'many', 'thanks']
# ['listen', 'last', 'night', ':)', 'bleed', 'amazing', 'track', 'scotland']
# ['congrats', ':)']
# ['yeaaah', 'yipppy', 'accnt', 'verified', 'rqst', 'succeed', 'got', 'blue', 'tick', 'mark', 'fb', 'profile', ':)', '15', 'days']

# %% [markdown]
# ## Stemming

# %%
# STEMMING USING PORTER STEMMING ALGORITHM


def stemming(tweet):
    stemmer = PorterStemmer()
    
    tweet_stemmed = []  # TO STORE STEMMED TWEET
    
        # ITERATE EACH WORD/TOKEN IN TWEET
    for word in tweet:
        stem_word = stemmer.stem(word)  # STEMMING
        tweet_stemmed.append(stem_word)  # PUSH STEMMED TOKEN

    return tweet_stemmed

# %%
# DISPLAY TWEET/TOKEN AFTER STEMMING

i = 0
tweet_stemmed = []

print('Tweet After Stemming : ')

for tweet in cleaned_tweets:
    stem = stemming(tweet)

    # JUST PRINT THE FIRST 5 TWEET
    if i < 5:
        print(stem)

    i += 1
    tweet_stemmed.append(stem)
# Out:
# Tweet After Stemming :
# ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ['hey', 'jame', 'odd', ':/', 'pleas', 'call', 'contact', 'centr', '02392441234', 'abl', 'assist', ':)', 'mani', 'thank']
# ['listen', 'last', 'night', ':)', 'bleed', 'amaz', 'track', 'scotland']
# ['congrat', ':)']
# ['yeaaah', 'yipppi', 'accnt', 'verifi', 'rqst', 'succeed', 'got', 'blue', 'tick', 'mark', 'fb', 'profil', ':)', '15', 'day']

# %% [markdown]
# ## Frequency Each Token

# %%
# FREQUENCY DICT 

frequency_token = {}

# ITERATE EVERY LABEL AND TWEETS
for label , tweets in zip(train_label, tweet_stemmed):
    for word in tweets:
        pair = (word, int(label))

        if pair in frequency_token:
            frequency_token[pair] += 1
        else:
            frequency_token[pair] = 1

# DISPLAY RESULT 
len(frequency_token) , frequency_token
# Out:
# C:\Users\aliff\AppData\Local\Temp\ipykernel_13328\876181935.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   pair = (word, int(label))
# (11420,
#  {('followfriday', 1): 23,
#   ('top', 1): 30,
#   ('engag', 1): 7,
#   ('member', 1): 14,
#   ('commun', 1): 27,
#   ('week', 1): 72,
#   (':)', 1): 2960,
#   ('hey', 1): 60,
#   ('jame', 1): 7,
#   ('odd', 1): 2,
#   (':/', 1): 5,
#   ('pleas', 1): 81,
#   ('call', 1): 27,
#   ('contact', 1): 4,
#   ('centr', 1): 1,
#   ('02392441234', 1): 1,
#   ('abl', 1): 6,
#   ('assist', 1): 1,
#   ('mani', 1): 28,
#   ('thank', 1): 522,
#   ('listen', 1): 15,
#   ('last', 1): 39,
#   ('night', 1): 55,
#   ('bleed', 1): 2,
#   ('amaz', 1): 41,
#   ('track', 1): 5,
#   ('scotland', 1): 2,
#   ('congrat', 1): 15,
#   ('yeaaah', 1): 1,
#   ('yipppi', 1): 1,
#   ('accnt', 1): 2,
#   ('verifi', 1): 2,
#   ('rqst', 1): 1,
#   ('succeed', 1): 1,
#   ('got', 1): 57,
#   ('blue', 1): 8,
#   ('tick', 1): 1,
#   ('mark', 1): 1,
#   ('fb', 1): 4,
#   ('profil', 1): 2,
#   ('15', 1): 4,
#   ('day', 1): 187,
#   ('one', 1): 92,
#   ('irresist', 1): 2,
#   ('flipkartfashionfriday', 1): 16,
#   ('like', 1): 187,
#   ('keep', 1): 55,
#   ('love', 1): 336,
#   ('custom', 1): 4,
#   ('wait', 1): 55,
#   ('long', 1): 27,
#   ('hope', 1): 115,
#   ('enjoy', 1): 61,
#   ('happi', 1): 162,
#   ('friday', 1): 91,
#   ('lwwf', 1): 1,
#   ('second', 1): 8,
#   ('thought', 1): 21,
#   ('’', 1): 17,
#   ('enough', 1): 16,
#   ('time', 1): 101,
#   ('dd', 1): 1,
#   ('new', 1): 114,
#   ('short', 1): 6,
#   ('enter', 1): 9,
#   ('system', 1): 2,
#   ('sheep', 1): 1,
#   ('must', 1): 14,
#   ('buy', 1): 10,
#   ('jgh', 1): 4,
#   ('go', 1): 123,
#   ('bayan', 1): 1,
#   (':d', 1): 523,
#   ('bye', 1): 5,
#   ('act', 1): 6,
#   ('mischiev', 1): 1,
#   ('etl', 1): 1,
#   ('layer', 1): 1,
#   ('in-hous', 1): 1,
#   ('wareh', 1): 1,
#   ('app', 1): 12,
#   ('katamari', 1): 1,
#   ('well', 1): 66,
#   ('…', 1): 31,
#   ('name', 1): 12,
#   ('impli', 1): 1,
#   (':p', 1): 105,
#   ('influenc', 1): 16,
#   ('big', 1): 28,
#   ('...', 1): 228,
#   ('juici', 1): 3,
#   ('selfi', 1): 11,
#   ('follow', 1): 385,
#   ('u', 1): 204,
#   ('back', 1): 139,
#   ('perfect', 1): 17,
#   ('alreadi', 1): 19,
#   ('know', 1): 128,
#   ("what'", 1): 14,
#   ('great', 1): 135,
#   ('opportun', 1): 17,
#   ('junior', 1): 2,
#   ('triathlet', 1): 1,
#   ('age', 1): 2,
#   ('12', 1): 5,
#   ('13', 1): 5,
#   ('gatorad', 1): 1,
#   ('seri', 1): 4,
#   ('get', 1): 166,
#   ('entri', 1): 3,
#   ('lay', 1): 3,
#   ('greet', 1): 4,
#   ('card', 1): 6,
#   ('rang', 1): 2,
#   ('print', 1): 4,
#   ('today', 1): 91,
#   ('job', 1): 34,
#   (':-)', 1): 552,
#   ("friend'", 1): 3,
#   ('lunch', 1): 3,
#   ('yummm', 1): 1,
#   ('nostalgia', 1): 1,
#   ('tb', 1): 1,
#   ('ku', 1): 1,
#   ('id', 1): 8,
#   ('conflict', 1): 1,
#   ('help', 1): 40,
#   ("here'", 1): 20,
#   ('screenshot', 1): 2,
#   ('work', 1): 89,
#   ('hi', 1): 154,
#   ('liv', 1): 2,
#   ('hello', 1): 49,
#   ('need', 1): 62,
#   ('someth', 1): 25,
#   ('fm', 1): 2,
#   ('twitter', 1): 25,
#   ('—', 1): 22,
#   ('sure', 1): 38,
#   ('thing', 1): 48,
#   ('dm', 1): 34,
#   ('x', 1): 50,
#   ("i'v", 1): 25,
#   ('heard', 1): 9,
#   ('four', 1): 5,
#   ('season', 1): 5,
#   ('pretti', 1): 17,
#   ('dope', 1): 2,
#   ('penthous', 1): 1,
#   ('obv', 1): 1,
#   ('gobigorgohom', 1): 1,
#   ('fun', 1): 45,
#   ("y'all", 1): 4,
#   ('yeah', 1): 30,
#   ('suppos', 1): 6,
#   ('lol', 1): 48,
#   ('chat', 1): 9,
#   ('bit', 1): 16,
#   ('youth', 1): 14,
#   ('💅🏽', 1): 1,
#   ('💋', 1): 2,
#   ('seen', 1): 6,
#   ('year', 1): 33,
#   ('rest', 1): 9,
#   ('goe', 1): 4,
#   ('quickli', 1): 3,
#   ('bed', 1): 8,
#   ('music', 1): 15,
#   ('fix', 1): 6,
#   ('dream', 1): 17,
#   ('spiritu', 1): 1,
#   ('ritual', 1): 1,
#   ('festiv', 1): 7,
#   ('népal', 1): 1,
#   ('begin', 1): 4,
#   ('line-up', 1): 4,
#   ('left', 1): 10,
#   ('see', 1): 157,
#   ('sarah', 1): 4,
#   ('send', 1): 18,
#   ('us', 1): 96,
#   ('email', 1): 22,
#   ('bitsy.com', 1): 1,
#   ("we'll", 1): 12,
#   ('asap', 1): 5,
#   ('kik', 1): 16,
#   ('hatessuc', 1): 1,
#   ('32429', 1): 1,
#   ('kikm', 1): 1,
#   ('lgbt', 1): 2,
#   ('tinder', 1): 1,
#   ('nsfw', 1): 1,
#   ('akua', 1): 1,
#   ('cumshot', 1): 1,
#   ('come', 1): 63,
#   ('hous', 1): 5,
#   ('nsn_supplement', 1): 1,
#   ('effect', 1): 2,
#   ('press', 1): 1,
#   ('releas', 1): 11,
#   ('distribut', 1): 1,
#   ('result', 1): 2,
#   ('link', 1): 14,
#   ('remov', 1): 3,
#   ('pressreleas', 1): 1,
#   ('newsdistribut', 1): 1,
#   ('bam', 1): 44,
#   ('bestfriend', 1): 50,
#   ('lot', 1): 80,
#   ('warsaw', 1): 44,
#   ('<3', 1): 119,
#   ('x46', 1): 1,
#   ('everyon', 1): 45,
#   ('watch', 1): 32,
#   ('documentari', 1): 1,
#   ('earthl', 1): 1,
#   ('youtub', 1): 8,
#   ('support', 1): 25,
#   ('buuut', 1): 1,
#   ('oh', 1): 44,
#   ('look', 1): 111,
#   ('forward', 1): 20,
#   ('visit', 1): 25,
#   ('next', 1): 37,
#   ('letsgetmessi', 1): 1,
#   ('jo', 1): 1,
#   ('make', 1): 70,
#   ('feel', 1): 33,
#   ('better', 1): 40,
#   ('never', 1): 31,
#   ('anyon', 1): 7,
#   ('kpop', 1): 1,
#   ('flesh', 1): 1,
#   ('good', 1): 191,
#   ('girl', 1): 34,
#   ('best', 1): 49,
#   ('wish', 1): 29,
#   ('reason', 1): 10,
#   ('epic', 1): 1,
#   ('soundtrack', 1): 1,
#   ('shout', 1): 11,
#   ('ad', 1): 10,
#   ('video', 1): 30,
#   ('playlist', 1): 5,
#   ('im', 1): 41,
#   ('twitch', 1): 7,
#   ('leagu', 1): 6,
#   ('1', 1): 63,
#   ('4', 1): 23,
#   ('would', 1): 70,
#   ('dear', 1): 15,
#   ('jordan', 1): 1,
#   ('okay', 1): 31,
#   ('fake', 1): 1,
#   ('gameplay', 1): 1,
#   (';)', 1): 22,
#   ('haha', 1): 44,
#   ('kid', 1): 13,
#   ('stuff', 1): 11,
#   ('exactli', 1): 5,
#   ('product', 1): 11,
#   ('line', 1): 6,
#   ('etsi', 1): 1,
#   ('shop', 1): 12,
#   ('check', 1): 39,
#   ('boxroomcraft', 1): 1,
#   ('vacat', 1): 5,
#   ('recharg', 1): 1,
#   ('normal', 1): 5,
#   ('charger', 1): 2,
#   ('asleep', 1): 7,
#   ('talk', 1): 38,
#   ('sooo', 1): 6,
#   ('someon', 1): 29,
#   ('text', 1): 12,
#   ('ye', 1): 60,
#   ('bet', 1): 6,
#   ("he'll", 1): 2,
#   ('fit', 1): 2,
#   ('hear', 1): 24,
#   ('speech', 1): 1,
#   ('piti', 1): 2,
#   ('green', 1): 2,
#   ('garden', 1): 5,
#   ('midnight', 1): 1,
#   ('sun', 1): 6,
#   ('beauti', 1): 45,
#   ('canal', 1): 1,
#   ('dasvidaniya', 1): 1,
#   ('till', 1): 16,
#   ('scout', 1): 1,
#   ('sg', 1): 1,
#   ('futur', 1): 9,
#   ('wlan', 1): 1,
#   ('pro', 1): 4,
#   ('confer', 1): 1,
#   ('asia', 1): 1,
#   ('chang', 1): 20,
#   ('lollipop', 1): 1,
#   ('🍭', 1): 1,
#   ('nez', 1): 1,
#   ('agnezmo', 1): 1,
#   ('oley', 1): 1,
#   ('mama', 1): 1,
#   ('stand', 1): 6,
#   ('stronger', 1): 1,
#   ('god', 1): 14,
#   ('misti', 1): 1,
#   ('babi', 1): 17,
#   ('cute', 1): 22,
#   ('woohoo', 1): 3,
#   ("can't", 1): 31,
#   ('sign', 1): 9,
#   ('yet', 1): 12,
#   ('still', 1): 37,
#   ('think', 1): 54,
#   ('mka', 1): 5,
#   ('liam', 1): 5,
#   ('access', 1): 3,
#   ('welcom', 1): 54,
#   ('stat', 1): 51,
#   ('arriv', 1): 57,
#   ('unfollow', 1): 53,
#   ('via', 1): 73,
#   ('surpris', 1): 10,
#   ('figur', 1): 5,
#   ('happybirthdayemilybett', 1): 1,
#   ('sweet', 1): 16,
#   ('talent', 1): 4,
#   ('2', 1): 41,
#   ('plan', 1): 21,
#   ('drain', 1): 1,
#   ('gotta', 1): 4,
#   ('timezon', 1): 1,
#   ('parent', 1): 4,
#   ('proud', 1): 11,
#   ('least', 1): 14,
#   ('mayb', 1): 17,
#   ('sometim', 1): 11,
#   ('grade', 1): 4,
#   ('al', 1): 3,
#   ('grand', 1): 4,
#   ('manila_bro', 1): 1,
#   ('chosen', 1): 1,
#   ('let', 1): 70,
#   ('around', 1): 14,
#   ('..', 1): 100,
#   ('side', 1): 13,
#   ('world', 1): 23,
#   ('eh', 1): 2,
#   ('take', 1): 30,
#   ('care', 1): 12,
#   ('final', 1): 24,
#   ('fuck', 1): 20,
#   ('weekend', 1): 61,
#   ('real', 1): 18,
#   ('x45', 1): 1,
#   ('join', 1): 21,
#   ('hushedcallwithfraydo', 1): 1,
#   ('gift', 1): 7,
#   ('yeahhh', 1): 1,
#   ('hushedpinwithsammi', 1): 2,
#   ('event', 1): 8,
#   ('might', 1): 21,
#   ('luv', 1): 4,
#   ('realli', 1): 66,
#   ('appreci', 1): 28,
#   ('share', 1): 41,
#   ('wow', 1): 14,
#   ('tom', 1): 6,
#   ('3', 1): 27,
#   ('gym', 1): 3,
#   ('monday', 1): 7,
#   ('invit', 1): 15,
#   ('scope', 1): 5,
#   ('friend', 1): 43,
#   ('nude', 1): 1,
#   ('sleep', 1): 35,
#   ('birthday', 1): 53,
#   ('want', 1): 71,
#   ('t-shirt', 1): 2,
#   ('cool', 1): 29,
#   ('haw', 1): 1,
#   ('phela', 1): 1,
#   ('mom', 1): 7,
#   ('obvious', 1): 1,
#   ('princ', 1): 1,
#   ('charm', 1): 1,
#   ('stage', 1): 2,
#   ('luck', 1): 26,
#   ('tyler', 1): 1,
#   ('hipster', 1): 1,
#   ('glass', 1): 3,
#   ('marti', 1): 2,
#   ('glad', 1): 41,
#   ('done', 1): 40,
#   ('afternoon', 1): 7,
#   ('read', 1): 28,
#   ('kahfi', 1): 1,
#   ('finish', 1): 15,
#   ('ohmyg', 1): 1,
#   ('yaya', 1): 3,
#   ('dub', 1): 1,
#   ('stalk', 1): 2,
#   ('ig', 1): 3,
#   ('gondooo', 1): 1,
#   ('moo', 1): 2,
#   ('tologooo', 1): 1,
#   ('becom', 1): 8,
#   ('detail', 1): 8,
#   ('zzz', 1): 1,
#   ('xx', 1): 33,
#   ('physiotherapi', 1): 1,
#   ('hashtag', 1): 3,
#   ('💪', 1): 1,
#   ('monica', 1): 1,
#   ('miss', 1): 17,
#   ('sound', 1): 20,
#   ('morn', 1): 68,
#   ("that'", 1): 49,
#   ('x43', 1): 1,
#   ('definit', 1): 20,
#   ('tri', 1): 34,
#   ('tonight', 1): 15,
#   ('took', 1): 7,
#   ('advic', 1): 6,
#   ('treviso', 1): 1,
#   ('concert', 1): 23,
#   ('citi', 1): 26,
#   ('countri', 1): 22,
#   ("i'll", 1): 74,
#   ('start', 1): 56,
#   ('fine', 1): 7,
#   ('gorgeou', 1): 9,
#   ('xo', 1): 2,
#   ('oven', 1): 2,
#   ('roast', 1): 1,
#   ('garlic', 1): 1,
#   ('oliv', 1): 1,
#   ('oil', 1): 4,
#   ('dri', 1): 4,
#   ('tomato', 1): 1,
#   ('basil', 1): 1,
#   ('centuri', 1): 1,
#   ('tuna', 1): 1,
#   ('right', 1): 38,
#   ('atchya', 1): 1,
#   ('even', 1): 26,
#   ('almost', 1): 8,
#   ('chanc', 1): 3,
#   ('cheer', 1): 18,
#   ('po', 1): 3,
#   ('ice', 1): 6,
#   ('cream', 1): 6,
#   ('agre', 1): 13,
#   ('100', 1): 6,
#   ('heheheh', 1): 2,
#   ('that', 1): 10,
#   ('point', 1): 11,
#   ('stay', 1): 21,
#   ('home', 1): 20,
#   ('soon', 1): 38,
#   ('promis', 1): 4,
#   ('web', 1): 4,
#   ('whatsapp', 1): 3,
#   ('volta', 1): 1,
#   ('funcionar', 1): 1,
#   ('com', 1): 2,
#   ('iphon', 1): 7,
#   ('jailbroken', 1): 1,
#   ('later', 1): 12,
#   ('34', 1): 3,
#   ('min', 1): 7,
#   ('leia', 1): 1,
#   ('appear', 1): 3,
#   ('hologram', 1): 1,
#   ('r2d2', 1): 1,
#   ('w', 1): 16,
#   ('messag', 1): 9,
#   ('obi', 1): 1,
#   ('wan', 1): 1,
#   ('sit', 1): 7,
#   ('luke', 1): 4,
#   ('inter', 1): 1,
#   ('ucl', 1): 1,
#   ('arsen', 1): 2,
#   ('small', 1): 2,
#   ('team', 1): 24,
#   ('pass', 1): 10,
#   ('🚂', 1): 1,
#   ('dewsburi', 1): 2,
#   ('railway', 1): 1,
#   ('station', 1): 4,
#   ('dew', 1): 1,
#   ('west', 1): 1,
#   ('yorkshir', 1): 2,
#   ('430', 1): 1,
#   ('smh', 1): 2,
#   ('9:25', 1): 1,
#   ('live', 1): 23,
#   ('strang', 1): 4,
#   ('imagin', 1): 5,
#   ('megan', 1): 1,
#   ('masaantoday', 1): 4,
#   ('a4', 1): 3,
#   ('shweta', 1): 1,
#   ('tripathi', 1): 1,
#   ('5', 1): 15,
#   ('20', 1): 5,
#   ('kurta', 1): 3,
#   ('half', 1): 6,
#   ('number', 1): 11,
#   ('wsalelov', 1): 14,
#   ('ah', 1): 12,
#   ('larri', 1): 3,
#   ('anyway', 1): 14,
#   ('kinda', 1): 12,
#   ('goood', 1): 1,
#   ('life', 1): 36,
#   ('enn', 1): 1,
#   ('could', 1): 25,
#   ('warmup', 1): 1,
#   ('15th', 1): 2,
#   ('bath', 1): 6,
#   ('dum', 1): 2,
#   ('andar', 1): 1,
#   ('ram', 1): 1,
#   ('sampath', 1): 1,
#   ('sona', 1): 1,
#   ('mohapatra', 1): 1,
#   ('samantha', 1): 1,
#   ('edward', 1): 1,
#   ('mein', 1): 1,
#   ('tulan', 1): 1,
#   ('razi', 1): 2,
#   ('wah', 1): 2,
#   ('josh', 1): 1,
#   ('alway', 1): 48,
#   ('smile', 1): 47,
#   ('pictur', 1): 7,
#   ('16.20', 1): 1,
#   ('giveitup', 1): 1,
#   ('given', 1): 3,
#   ('ga', 1): 3,
#   ('subsidi', 1): 1,
#   ('initi', 1): 2,
#   ('propos', 1): 3,
#   ('delight', 1): 4,
#   ('yesterday', 1): 4,
#   ('x42', 1): 1,
#   ('lmaoo', 1): 2,
#   ('song', 1): 16,
#   ('ever', 1): 19,
#   ('shall', 1): 5,
#   ('littl', 1): 29,
#   ('throwback', 1): 3,
#   ('outli', 1): 1,
#   ('island', 1): 2,
#   ('cheung', 1): 1,
#   ('chau', 1): 1,
#   ('mui', 1): 1,
#   ('wo', 1): 1,
#   ('total', 1): 6,
#   ('differ', 1): 10,
#   ('kfckitchentour', 1): 2,
#   ('kitchen', 1): 3,
#   ('clean', 1): 1,
#   ("i'm", 1): 140,
#   ('cusp', 1): 1,
#   ('test', 1): 7,
#   ('water', 1): 7,
#   ('reward', 1): 1,
#   ('arummzz', 1): 2,
#   ("let'", 1): 20,
#   ('drive', 1): 9,
#   ('travel', 1): 19,
#   ('yogyakarta', 1): 3,
#   ('jeep', 1): 3,
#   ('indonesia', 1): 3,
#   ('instamood', 1): 3,
#   ('wanna', 1): 23,
#   ('skype', 1): 3,
#   ('may', 1): 16,
#   ('nice', 1): 71,
#   ('friendli', 1): 1,
#   ('pretend', 1): 2,
#   ('film', 1): 8,
#   ('congratul', 1): 9,
#   ('winner', 1): 3,
#   ('cheesydelight', 1): 1,
#   ('contest', 1): 5,
#   ('address', 1): 8,
#   ('guy', 1): 48,
#   ('market', 1): 5,
#   ('24/7', 1): 1,
#   ('regret', 1): 4,
#   ('14', 1): 1,
#   ('hour', 1): 24,
#   ('leav', 1): 12,
#   ('without', 1): 9,
#   ('delay', 1): 1,
#   ('actual', 1): 13,
#   ('easi', 1): 7,
#   ('guess', 1): 8,
#   ('train', 1): 7,
#   ('wd', 1): 1,
#   ('shift', 1): 4,
#   ('engin', 1): 1,
#   ('etc', 1): 2,
#   ('sunburn', 1): 1,
#   ('peel', 1): 2,
#   ('blog', 1): 27,
#   ('huge', 1): 9,
#   ('warm', 1): 4,
#   ('☆', 1): 3,
#   ('complet', 1): 10,
#   ('triangl', 1): 2,
#   ('northern', 1): 1,
#   ('ireland', 1): 2,
#   ('sight', 1): 1,
#   ('smthng', 1): 2,
#   ('fr', 1): 3,
#   ('hug', 1): 11,
#   ('xoxo', 1): 3,
#   ('uu', 1): 1,
#   ('jaann', 1): 1,
#   ('topnewfollow', 1): 2,
#   ('connect', 1): 13,
#   ('wonder', 1): 26,
#   ('made', 1): 38,
#   ('fluffi', 1): 1,
#   ('insid', 1): 7,
#   ('pirouett', 1): 1,
#   ('moos', 1): 1,
#   ('trip', 1): 12,
#   ('philli', 1): 1,
#   ('decemb', 1): 2,
#   ("i'd", 1): 13,
#   ('dude', 1): 6,
#   ('x41', 1): 1,
#   ('question', 1): 15,
#   ('flaw', 1): 1,
#   ('pain', 1): 8,
#   ('negat', 1): 1,
#   ('strength', 1): 2,
#   ('went', 1): 10,
#   ('solo', 1): 4,
#   ('move', 1): 9,
#   ('fav', 1): 11,
#   ('nirvana', 1): 1,
#   ('smell', 1): 2,
#   ('teen', 1): 3,
#   ('spirit', 1): 1,
#   ('rip', 1): 3,
#   ('ami', 1): 4,
#   ('winehous', 1): 1,
#   ('coupl', 1): 5,
#   ('tomhiddleston', 1): 1,
#   ('elizabetholsen', 1): 1,
#   ('yaytheylookgreat', 1): 1,
#   ('goodnight', 1): 18,
#   ('vid', 1): 8,
#   ('wake', 1): 10,
#   ('gonna', 1): 16,
#   ('shoot', 1): 5,
#   ('itti', 1): 2,
#   ('bitti', 1): 2,
#   ('teeni', 1): 2,
#   ('bikini', 1): 3,
#   ('much', 1): 73,
#   ('4th', 1): 4,
#   ('togeth', 1): 6,
#   ('end', 1): 13,
#   ('xfile', 1): 1,
#   ('content', 1): 3,
#   ('rain', 1): 18,
#   ('fabul', 1): 4,
#   ('fantast', 1): 9,
#   ('♡', 1): 12,
#   ('jb', 1): 1,
#   ('forev', 1): 5,
#   ('belieb', 1): 3,
#   ('nighti', 1): 1,
#   ('bug', 1): 2,
#   ('bite', 1): 1,
#   ('bracelet', 1): 2,
#   ('idea', 1): 24,
#   ('foundri', 1): 1,
#   ('game', 1): 23,
#   ('sens', 1): 6,
#   ('pic', 1): 21,
#   ('ef', 1): 1,
#   ('phone', 1): 16,
#   ('woot', 1): 2,
#   ('derek', 1): 1,
#   ('use', 1): 32,
#   ('parkshar', 1): 1,
#   ('gloucestershir', 1): 1,
#   ('aaaahhh', 1): 1,
#   ('man', 1): 16,
#   ('traffic', 1): 2,
#   ('stress', 1): 4,
#   ('reliev', 1): 1,
#   ("how'r", 1): 1,
#   ('arbeloa', 1): 1,
#   ('turn', 1): 14,
#   ('17', 1): 2,
#   ('omg', 1): 13,
#   ('say', 1): 43,
#   ('europ', 1): 1,
#   ('rise', 1): 2,
#   ('find', 1): 22,
#   ('hard', 1): 9,
#   ('believ', 1): 7,
#   ('uncount', 1): 1,
#   ('coz', 1): 2,
#   ('unlimit', 1): 1,
#   ('cours', 1): 11,
#   ('teamposit', 1): 1,
#   ('aldub', 1): 2,
#   ('☕', 1): 3,
#   ('rita', 1): 2,
#   ('info', 1): 11,
#   ("we'd", 1): 4,
#   ('way', 1): 34,
#   ('boy', 1): 13,
#   ('x40', 1): 1,
#   ('true', 1): 19,
#   ('sethi', 1): 2,
#   ('high', 1): 6,
#   ('exe', 1): 1,
#   ('skeem', 1): 1,
#   ('saam', 1): 1,
#   ('peopl', 1): 43,
#   ('polit', 1): 2,
#   ('izzat', 1): 1,
#   ('wese', 1): 1,
#   ('trust', 1): 7,
#   ('khawateen', 1): 1,
#   ('k', 1): 8,
#   ('sath', 1): 2,
#   ('mana', 1): 1,
#   ('kar', 1): 1,
#   ('deya', 1): 1,
#   ('sort', 1): 7,
#   ('smart', 1): 5,
#   ('hair', 1): 7,
#   ('tbh', 1): 5,
#   ('jacob', 1): 2,
#   ('g', 1): 8,
#   ('upgrad', 1): 2,
#   ('tee', 1): 3,
#   ('famili', 1): 14,
#   ('person', 1): 14,
#   ('two', 1): 15,
#   ('convers', 1): 6,
#   ('onlin', 1): 4,
#   ('mclaren', 1): 1,
#   ('fridayfeel', 1): 5,
#   ('tgif', 1): 8,
#   ('squar', 1): 1,
#   ('enix', 1): 1,
#   ('bissmillah', 1): 1,
#   ('ya', 1): 19,
#   ('allah', 1): 3,
#   ("we'r", 1): 26,
#   ('socent', 1): 1,
#   ('startup', 1): 2,
#   ('drop', 1): 9,
#   ('your', 1): 3,
#   ('arnd', 1): 1,
#   ('town', 1): 3,
#   ('basic', 1): 4,
#   ('piss', 1): 2,
#   ('cup', 1): 4,
#   ('also', 1): 29,
#   ('terribl', 1): 2,
#   ('complic', 1): 1,
#   ('discuss', 1): 2,
#   ('snapchat', 1): 31,
#   ('lynettelow', 1): 1,
#   ('kikmenow', 1): 2,
#   ('snapm', 1): 1,
#   ('hot', 1): 20,
#   ('amazon', 1): 1,
#   ('kikmeguy', 1): 2,
#   ('defin', 1): 2,
#   ('grow', 1): 6,
#   ('sport', 1): 4,
#   ('rt', 1): 9,
#   ('rakyat', 1): 1,
#   ('write', 1): 11,
#   ('sinc', 1): 11,
#   ('mention', 1): 18,
#   ('fli', 1): 5,
#   ('fish', 1): 4,
#   ('promot', 1): 3,
#   ('post', 1): 16,
#   ('cyber', 1): 1,
#   ('ourdaughtersourprid', 1): 3,
#   ('mypapamyprid', 1): 2,
#   ('papa', 1): 1,
#   ('coach', 1): 2,
#   ('posit', 1): 3,
#   ('kha', 1): 1,
#   ('atleast', 1): 2,
#   ('x39', 1): 1,
#   ('mango', 1): 1,
#   ("lassi'", 1): 1,
#   ("monty'", 1): 1,
#   ('marvel', 1): 2,
#   ('though', 1): 16,
#   ('suspect', 1): 3,
#   ('meant', 1): 2,
#   ('24', 1): 3,
#   ('hr', 1): 2,
#   ('touch', 1): 7,
#   ('kepler', 1): 3,
#   ('452b', 1): 4,
#   ('chalna', 1): 1,
#   ('hai', 1): 7,
#   ('thankyou', 1): 12,
#   ('hazel', 1): 1,
#   ('food', 1): 10,
#   ('brooklyn', 1): 1,
#   ('pta', 1): 2,
#   ('awak', 1): 8,
#   ('okayi', 1): 2,
#   ('awww', 1): 12,
#   ('ha', 1): 18,
#   ('doc', 1): 1,
#   ('splendid', 1): 1,
#   ('spam', 1): 1,
#   ('folder', 1): 1,
#   ('amount', 1): 1,
#   ('nigeria', 1): 1,
#   ('claim', 1): 1,
#   ('rted', 1): 1,
#   ('leg', 1): 3,
#   ('hurt', 1): 4,
#   ('bad', 1): 14,
#   ('mine', 1): 11,
#   ('saturday', 1): 5,
#   ('thaaank', 1): 1,
#   ('puhon', 1): 1,
#   ('happinesss', 1): 1,
#   ('tnc', 1): 1,
#   ('prior', 1): 1,
#   ('notif', 1): 2,
#   ('probabl', 1): 8,
#   ('funni', 1): 16,
#   ('2:22', 1): 1,
#   ('fat', 1): 1,
#   ('co', 1): 1,
#   ('ate', 1): 4,
#   ('yuna', 1): 2,
#   ('tamesid', 1): 1,
#   ('´', 1): 3,
#   ('googl', 1): 5,
#   ('account', 1): 17,
#   ('scouser', 1): 1,
#   ('everyth', 1): 10,
#   ('zoe', 1): 1,
#   ('mate', 1): 5,
#   ('liter', 1): 6,
#   ("they'r", 1): 10,
#   ('samee', 1): 1,
#   ('edgar', 1): 1,
#   ('updat', 1): 12,
#   ('log', 1): 3,
#   ('bring', 1): 14,
#   ('abe', 1): 1,
#   ('meet', 1): 26,
#   ('x38', 1): 1,
#   ('sigh', 1): 3,
#   ('dreamili', 1): 1,
#   ('pout', 1): 1,
#   ('eye', 1): 12,
#   ('quacketyquack', 1): 6,
#   ('happen', 1): 13,
#   ('phil', 1): 1,
#   ('em', 1): 2,
#   ('del', 1): 1,
#   ('rodder', 1): 1,
#   ('els', 1): 8,
#   ('play', 1): 37,
#   ('newest', 1): 1,
#   ('gamejam', 1): 1,
#   ('irish', 1): 2,
#   ('literatur', 1): 2,
#   ('inaccess', 1): 2,
#   ("kareena'", 1): 2,
#   ('fan', 1): 21,
#   ('brain', 1): 10,
#   ('dot', 1): 8,
#   ('braindot', 1): 8,
#   ('fair', 1): 4,
#   ('rush', 1): 1,
#   ('either', 1): 10,
#   ('brandi', 1): 1,
#   ('18', 1): 5,
#   ('carniv', 1): 1,
#   ('men', 1): 8,
#   ('put', 1): 11,
#   ('mask', 1): 2,
#   ('xavier', 1): 1,
#   ('forneret', 1): 1,
#   ('jennif', 1): 1,
#   ('site', 1): 7,
#   ('free', 1): 32,
#   ('50.000', 1): 3,
#   ('8', 1): 11,
#   ('ball', 1): 7,
#   ('pool', 1): 5,
#   ('coin', 1): 5,
#   ('edit', 1): 6,
#   ('trish', 1): 1,
#   ('♥', 1): 13,
#   ('grate', 1): 5,
#   ('three', 1): 8,
#   ('comment', 1): 8,
#   ('wakeup', 1): 1,
#   ('besid', 1): 2,
#   ('dirti', 1): 2,
#   ('sex', 1): 4,
#   ('lmaooo', 1): 1,
#   ('😤', 1): 2,
#   ('loui', 1): 4,
#   ("he'", 1): 11,
#   ('throw', 1): 3,
#   ('caus', 1): 11,
#   ('inspir', 1): 6,
#   ('ff', 1): 40,
#   ('twoof', 1): 3,
#   ('gr8', 1): 1,
#   ('wkend', 1): 3,
#   ('kind', 1): 22,
#   ('exhaust', 1): 2,
#   ('word', 1): 17,
#   ('cheltenham', 1): 1,
#   ('area', 1): 4,
#   ('9', 1): 3,
#   ('kale', 1): 1,
#   ('crisp', 1): 1,
#   ('ruin', 1): 5,
#   ('x37', 1): 1,
#   ('open', 1): 12,
#   ('worldwid', 1): 2,
#   ('outta', 1): 1,
#   ('sfvbeta', 1): 1,
#   ('vantast', 1): 1,
#   ('xcylin', 1): 1,
#   ('bundl', 1): 1,
#   ('show', 1): 20,
#   ('internet', 1): 2,
#   ('price', 1): 3,
#   ('realisticli', 1): 1,
#   ('pay', 1): 8,
#   ('net', 1): 1,
#   ('educ', 1): 1,
#   ('power', 1): 6,
#   ('weapon', 1): 1,
#   ('nelson', 1): 1,
#   ('mandela', 1): 1,
#   ('recent', 1): 8,
#   ('j', 1): 2,
#   ('chenab', 1): 1,
#   ('flow', 1): 5,
#   ('pakistan', 1): 1,
#   ('incredibleindia', 1): 1,
#   ('teenchoic', 1): 7,
#   ('choiceinternationalartist', 1): 7,
#   ('superjunior', 1): 7,
#   ('caught', 1): 4,
#   ('first', 1): 41,
#   ('salmon', 1): 1,
#   ('super-blend', 1): 1,
#   ('project', 1): 6,
#   ('youth.org.uk', 1): 1,
#   ('awesom', 1): 35,
#   ('stream', 1): 12,
#   ('artist', 1): 2,
#   ('alma', 1): 1,
#   ('mater', 1): 1,
#   ('highschoolday', 1): 1,
#   ('clientvisit', 1): 1,
#   ('faith', 1): 3,
#   ('christian', 1): 1,
#   ('school', 1): 9,
#   ('lizaminnelli', 1): 1,
#   ('upcom', 1): 2,
#   ('uk', 1): 4,
#   ('😄', 1): 3,
#   ('singl', 1): 4,
#   ('hill', 1): 4,
#   ('everi', 1): 23,
#   ('beat', 1): 7,
#   ('wrong', 1): 9,
#   ('readi', 1): 22,
#   ('natur', 1): 1,
#   ...})

# %% [markdown]
# create  function Pipeline for shortcut cleaning text

# %%
# Pipeline Function

def tokenizer(tweet):
    cleaning_tweet = TextCleaning(tweet)
    tweet_token    = Tokenization(cleaning_tweet)
    cleaned_token  = remove_StopWords(tweet_token)
    stemmed_token  = stemming(cleaned_token)

    return stemmed_token

# %% [markdown]
# # Train Model

# %% [markdown]
# create naive bayes with logarithm formula

# %% [markdown]
# The naive Bayes logarithm formula consists of 2 components, namely:

# %% [markdown]
# <pre>
# 1. Logprior : log( P(positif)
#                   ____________
#                   P(Negatif) )
#
# </pre>

# %% [markdown]
# <pre>
# 2. Loglikelihood = log ( P(token | positif)
#                        _____________________
#                         P(token | negatif) )
#
#
# </pre>

# %% [markdown]
# <pre>
# 3. Laplacian Correction (Smoothing) :        P(label_i ) + 1
#                                       ____________________________
#                                       N_label_i + total unique word
#
#
# </pre>

# %%
def train_naive_bayes(frequency_token, labels):

    # DECLARE VARIABLE FOR LOGPRIOR AND LOGLIKELIHOOD
    logprior      = 0
    loglikelihood = {}

    # SELECT UNIQUE TOKEN/WORD
    vocab              = [word for word , _ in frequency_token.keys()]
    total_unique_word = len(vocab)


    # COMPUTE LOGPRIOR
    total_tweet = len(labels)
    total_positive_tweet = total_negative_tweet = 0

    # COUNT HOW MUCH POSITIVE AND NEGATIVE TWEET IN 1 DOCUMENT (DATASET)
    for label in labels:
        if label == 1:
            total_positive_tweet += 1
        else:
            total_negative_tweet += 1
    
    logprior = np.log(total_positive_tweet / total_tweet) - np.log(total_negative_tweet / total_tweet)

    # AFTER COMPUTE LOGPRIOR , NEXT COMPUTE LOGLIKELIHOOD

    # BEFORE THAT , LETS FIND LAPLACIAN SMOOTHING FIRST
    
    vocab = set([word for word, _ in frequency_token.keys()])   # UNIQUE WORD
    total_word = len(vocab)
    
    N_pos = N_neg = 0
    for pair in frequency_token.keys():
        # IF LABEL IS POSITIVE
        if pair[1] > 0:
            N_pos += frequency_token[pair]
        else:
            N_neg += frequency_token[pair]

    # COMPUTE PROBABILITIES EVERY WORD
    for word in vocab:
        total_positive_word = frequency_token.get((word,1), 0)
        total_negative_word = frequency_token.get((word,0), 0)

        # COMPUTE LAPLACIAN 
        laplacian_positive = (total_positive_word + 1) / (N_pos + total_word)
        laplacian_negative = (total_negative_word + 1) / (N_neg + total_word)

        # COMPUTE LOGLIKELIHOOD FOR EVERY WORD 
        loglikelihood[word] = np.log(laplacian_positive) - np.log(laplacian_negative)

    return logprior , loglikelihood

# %%
# CLEANING ENTIRE TRAIN DATA TWEETS

logprior , loglikelihood = train_naive_bayes(frequency_token, train_label)

if logprior > 0:
    print(f'there are more Positive Tweets in the dataset, with value logprior {logprior}')
elif logprior < 0:
    print(f'there are more Negative Tweets in the Dataset, with value of logprior {logprior}')
else:
    print(f'positive and negative tweets are balanced, with value of logprior {logprior}')
# Out:
# positive and negative tweets are balanced, with value of logprior 0.0

# %%
# CHECK PROBABILITIES EVERY WORD
loglikelihood
# Out:
# {'score': -0.7040528921548113,
#  'thread': -0.7040528921548113,
#  '🍤': 1.5985322008392355,
#  'tf': -1.3972000727147567,
#  'mic': -0.7040528921548113,
#  'bought': -0.8582035719820684,
#  '65': -0.7040528921548113,
#  'orlean': 0.6822414689650795,
#  'nuclear': -0.7040528921548113,
#  'mbasa': -0.7040528921548113,
#  '2013': -0.7040528921548113,
#  'logic': 0.6822414689650795,
#  'whip': -0.010905711594865863,
#  'exam': -0.010905711594864087,
#  'wacki': 0.6822414689650795,
#  'baat': 0.6822414689650795,
#  'slovenia': 1.087706577073245,
#  'comeback': -0.4163708197030296,
#  '{:': -0.7040528921548113,
#  'juja': -0.7040528921548113,
#  'himseek': -0.7040528921548113,
#  'great': 2.129160451901406,
#  '😢': -1.8026651808229204,
#  'confess': 0.6822414689650795,
#  'wast': -1.109518000262975,
#  'kunoriforceo': 1.7808537576331886,
#  'separ': 0.6822414689650795,
#  'ikea': -0.7040528921548113,
#  'bae': -0.48090934084060066,
#  'hiya': 0.6822414689650795,
#  'tempt': -1.109518000262975,
#  'detail': 0.8000245046214634,
#  'ever': -0.27326997606235626,
#  'upon': -0.010905711594865863,
#  'ugh': -2.4958123613828658,
#  '42': -0.7040528921548113,
#  'posey': 0.6822414689650795,
#  'basketbal': 1.087706577073245,
#  'x39': 0.6822414689650795,
#  'ella': -0.7040528921548113,
#  'stud': -0.7040528921548113,
#  'brk': -0.7040528921548113,
#  'hangout': -1.109518000262975,
#  'pussi': 0.2767763608569158,
#  'actuallythough': 0.6822414689650795,
#  'aa': 1.375388649525025,
#  'eintlik': -0.7040528921548113,
#  'ne': -1.3972000727147567,
#  'get': -0.1023980520195309,
#  '326': -0.7040528921548113,
#  'kia': -0.010905711594865863,
#  'spinni': -0.7040528921548113,
#  'genial': 0.6822414689650795,
#  'ign': 1.087706577073245,
#  'varieti': 0.6822414689650795,
#  'nvm': -1.109518000262975,
#  'swerv': 0.6822414689650795,
#  'panem': -0.7040528921548113,
#  'hund': -0.7040528921548113,
#  'trespass': -0.7040528921548113,
#  'laiten': 0.6822414689650795,
#  'exploit': 0.6822414689650795,
#  'mexican': 0.6822414689650795,
#  'maaf': 0.6822414689650795,
#  'hitmark': -0.7040528921548113,
#  'oracl': 0.6822414689650795,
#  'emma': -1.109518000262975,
#  'gin': -0.7040528921548113,
#  'lol.hook': 0.6822414689650795,
#  'contract': 0.6822414689650795,
#  'rais': 0.39455939651329963,
#  'hypercholesteloremia': -0.7040528921548113,
#  'super-blend': 0.6822414689650795,
#  '452096': 0.6822414689650795,
#  'uuughhh': -0.7040528921548113,
#  'fitn': -0.7040528921548113,
#  'greymind': -0.7040528921548113,
#  'abouti': -0.7040528921548113,
#  'reassur': 0.6822414689650795,
#  'everytim': 1.375388649525025,
#  'got': -0.46132220756529563,
#  '✔': -0.7040528921548113,
#  'tile': 0.6822414689650795,
#  'boaz': -0.7040528921548113,
#  'gto': 0.6822414689650795,
#  'paper': -1.1895607079365114,
#  'cooper': -0.7040528921548113,
#  '3week': 0.6822414689650795,
#  'roomi': 0.6822414689650795,
#  'ramadhan': -0.7040528921548113,
#  '💟': 1.087706577073245,
#  'katekyn': -0.7040528921548113,
#  'holist': 0.6822414689650795,
#  'bbygurl': -0.7040528921548113,
#  'yippee': 0.6822414689650795,
#  'eyyah': -0.7040528921548113,
#  'flower': 0.9053850202792901,
#  'jace': -0.7040528921548113,
#  'muriel': -0.7040528921548113,
#  '9muse': -0.7040528921548113,
#  'nerd': 1.087706577073245,
#  'mythic': 0.6822414689650795,
#  'fabian': -1.109518000262975,
#  'central': 1.087706577073245,
#  'corbyn': -0.7040528921548113,
#  'yapster': 0.6822414689650795,
#  'knive': -0.010905711594865863,
#  'commerci': 0.6822414689650795,
#  '. .': 0.39455939651329963,
#  'noooo': -0.7040528921548113,
#  'afternon': 0.6822414689650795,
#  '👑': -0.7040528921548113,
#  'narrow': 0.6822414689650795,
#  'nk': -0.7040528921548113,
#  'educampakl': 0.6822414689650795,
#  'bodo': -0.7040528921548113,
#  'patriot': 0.6822414689650795,
#  '9': -0.4163708197030296,
#  'gay': -0.5705214995302885,
#  'addm': 0.6822414689650795,
#  'speed': -1.109518000262975,
#  ':d': 6.250585972726177,
#  'ash': 0.6822414689650795,
#  'delph': -1.8026651808229204,
#  'homey': 0.6822414689650795,
#  'jilla': 0.6822414689650795,
#  'endlessli': -0.7040528921548113,
#  'maxfreshmov': 1.087706577073245,
#  'viner': -0.7040528921548113,
#  'gion': -0.7040528921548113,
#  'may': 0.0497189102215696,
#  'surpris': 0.5952300919754503,
#  'fridayfreebi': 0.6822414689650795,
#  'follow': 0.4355433212419886,
#  'forneret': 0.6822414689650795,
#  'foampit': 0.6822414689650795,
#  'thought': -0.2871590882230235,
#  'seven': 1.087706577073245,
#  'credit': 0.21223783971934473,
#  'bag': -0.3473779482160779,
#  'halfway': 0.6822414689650795,
#  'choroo': 0.6822414689650795,
#  'studio': -0.7040528921548113,
#  'ivi': 0.6822414689650795,
#  'ol': -0.010905711594864087,
#  'whimper': -0.7040528921548113,
#  'okok': 0.6822414689650795,
#  'old-porridg': 0.6822414689650795,
#  'footbal': -0.7040528921548113,
#  'domino': 0.6822414689650795,
#  'rodfanta': -0.7040528921548113,
#  'innoc': -0.7040528921548113,
#  'hoki': 0.6822414689650795,
#  'charad': -0.7040528921548113,
#  'edit': 0.325566525026348,
#  '6-5': 0.6822414689650795,
#  'retweet': 1.8608964653067268,
#  'supris': 0.6822414689650795,
#  'warmup': 0.6822414689650795,
#  'panda': 1.0877065770732433,
#  'vote': 0.14324496823239308,
#  'nanci': 0.6822414689650795,
#  'format': 0.6822414689650795,
#  'knowww': -0.7040528921548113,
#  'prophet': 0.6822414689650795,
#  'highschoolday': 0.6822414689650795,
#  'heswifi': 0.6822414689650795,
#  'beato': -0.7040528921548113,
#  'memotohat': 0.6822414689650795,
#  '9/11': -0.7040528921548113,
#  'goin': -0.010905711594865863,
#  'graciou': 0.6822414689650795,
#  '0345': 1.087706577073245,
#  'beatport': 0.6822414689650795,
#  'mwah': -0.7040528921548113,
#  'dine': 0.6822414689650795,
#  'ape': 0.6822414689650795,
#  'juudiciari': -0.7040528921548113,
#  "how'r": 0.6822414689650795,
#  'mehtab': 0.6822414689650795,
#  'neat-o': -0.7040528921548113,
#  'habe': -0.7040528921548113,
#  'postcod': -0.7040528921548113,
#  'poem': 0.6822414689650795,
#  '444': 0.6822414689650795,
#  '590': -0.7040528921548113,
#  'wreck': -0.7040528921548113,
#  'decor': 0.6822414689650795,
#  'daili': -0.010905711594864087,
#  'overwhelm': -0.010905711594865863,
#  'free': 0.7775516487694052,
#  'shi': -0.7040528921548113,
#  'crowdfund': 0.6822414689650795,
#  'males': 0.6822414689650795,
#  'taco': -0.010905711594864087,
#  'bend': 1.087706577073245,
#  '07:17': -1.109518000262975,
#  'seouljin': 0.6822414689650795,
#  'aqui': 2.291679381399181,
#  'upcom': 1.087706577073245,
#  'sunris': -0.7040528921548113,
#  'disgust': -1.9568158606501793,
#  'appeal': -0.010905711594865863,
#  'netflix': -1.6203436240289655,
#  'akshaymostlovedsuperstarev': 0.6822414689650795,
#  'beast': -0.7040528921548113,
#  'aint': -1.109518000262975,
#  'pregnanc': -0.7040528921548113,
#  'bye': -0.1650563914221248,
#  'feelinggood': 0.6822414689650795,
#  'vomit': -0.7040528921548113,
#  'hinanap': -0.7040528921548113,
#  'muv': -0.7040528921548113,
#  'fc': -0.010905711594865863,
#  'kno': 0.6822414689650795,
#  'yep': 0.2767763608569158,
#  'silang': -0.7040528921548113,
#  'tiredashel': -0.7040528921548113,
#  'fuq': -0.7040528921548113,
#  'adam': -0.010905711594865863,
#  'rogerwatch': -0.7040528921548113,
#  'edwin': 0.6822414689650795,
#  '15th': 1.087706577073245,
#  'damag': -1.8026651808229204,
#  'x12': 1.087706577073245,
#  'suzan': 0.6822414689650795,
#  '340': -0.7040528921548113,
#  'dnt': -0.010905711594865863,
#  'ep': -0.010905711594865863,
#  'bruce': -0.010905711594865863,
#  'megamoh': 0.6822414689650795,
#  'jillcruz': -1.109518000262975,
#  'banda': 0.6822414689650795,
#  'con': 0.6822414689650795,
#  'sbenu': -0.7040528921548113,
#  '¦': 0.6822414689650795,
#  'critic': -0.7040528921548113,
#  'sub': 0.39455939651329963,
#  'pea': -0.7040528921548113,
#  'bright': -0.4163708197030296,
#  'fraud': -0.7040528921548113,
#  'grumpi': -1.6203436240289655,
#  'cortez': 0.6822414689650795,
#  'madi': -1.109518000262975,
#  'kit': -0.9271964434690201,
#  'cocktaili': -0.7040528921548113,
#  'choreo': -0.7040528921548113,
#  'yun': -0.7040528921548113,
#  'callinganimalabusehotlineasap': 0.6822414689650795,
#  'hardli': -0.4163708197030296,
#  'tose': 0.6822414689650795,
#  'tagsforlik': -0.23404926290907468,
#  "apma'": -0.7040528921548113,
#  'malta': 0.6822414689650795,
#  'iso': 0.6822414689650795,
#  ":')": 1.087706577073245,
#  'aim': 0.6822414689650795,
#  'traffick': -0.010905711594865863,
#  'foundri': 0.6822414689650795,
#  'round': -0.010905711594864087,
#  'barnstapl': 0.6822414689650795,
#  'ingat': 0.6822414689650795,
#  'grown': -1.109518000262975,
#  'seed': 1.375388649525025,
#  'worldwid': 1.087706577073245,
#  'lyka': 0.6822414689650795,
#  'shit': -0.8218359278111951,
#  'guitar': -0.010905711594865863,
#  'nowaday': 0.6822414689650795,
#  'tweng': -0.7040528921548113,
#  'gr': 0.6822414689650795,
#  'amat': -0.7040528921548113,
#  'juic': 0.6822414689650795,
#  '┣': 0.6822414689650795,
#  'carniv': 0.6822414689650795,
#  'hide': -0.29858778404664577,
#  'snake': -0.7040528921548113,
#  'juan': -0.010905711594865863,
#  'chapter': -0.7040528921548113,
#  'raiz': -0.7040528921548113,
#  'mastership': 0.6822414689650795,
#  'forget': 1.0305481632332958,
#  'sholong': -0.7040528921548113,
#  'louisianashoot': -0.7040528921548113,
#  'bias': -0.7040528921548113,
#  'bissmillah': 0.6822414689650795,
#  'tim': -0.010905711594864087,
#  'mustread': 0.6822414689650795,
#  'hasya': -0.7040528921548113,
#  'awuuu': 0.6822414689650795,
#  'jangli': 0.6822414689650795,
#  'subway': -0.7040528921548113,
#  'quacketyquack': 1.9350044374604476,
#  '4-6': -0.010905711594865863,
#  "joe'": 0.6822414689650795,
#  '1,500': -0.7040528921548113,
#  'newsround': 0.6822414689650795,
#  'lolzz': -0.7040528921548113,
#  'sengenza': -0.7040528921548113,
#  'plain': -0.7040528921548113,
#  '╯': 1.375388649525025,
#  'plea': -1.109518000262975,
#  'donutsss': -0.7040528921548113,
#  'youthcelebr': 0.6822414689650795,
#  'taught': 0.6822414689650795,
#  'beanatividad': 0.6822414689650795,
#  'hediy': 0.6822414689650795,
#  'start': 0.39455939651329874,
#  'prime': 1.087706577073245,
#  'ti5': -0.010905711594865863,
#  'sampath': 0.6822414689650795,
#  'aunt': 0.6822414689650795,
#  'cow': -0.7040528921548113,
#  'belieb': 0.6822414689650795,
#  'ryan': 0.6822414689650795,
#  'mirror': 0.6822414689650795,
#  'kin': 0.6822414689650795,
#  'anarchi': -0.7040528921548113,
#  'mr2': 0.6822414689650795,
#  'doli': 0.6822414689650795,
#  'ahahah': -0.010905711594865863,
#  'salmon': 0.6822414689650795,
#  'epiphani': 0.6822414689650795,
#  'yogyakarta': 1.375388649525025,
#  'juici': 1.375388649525025,
#  'auvssscr': 0.6822414689650795,
#  'lvg': -0.7040528921548113,
#  'photoshop': -1.109518000262975,
#  'noe': 0.6822414689650795,
#  'hastili': 0.6822414689650795,
#  'champion': 0.6822414689650795,
#  'woot': 1.087706577073245,
#  'x32': 0.6822414689650795,
#  'prexi': -0.7040528921548113,
#  'bap': -0.7040528921548113,
#  'bit': 0.257358274999814,
#  'lwwf': 0.6822414689650795,
#  'kikkomansabor': 0.39455939651329963,
#  'keedz': -0.7040528921548113,
#  'weekend': 1.0251862200919106,
#  'oth': 0.6822414689650795,
#  'raini': -0.4163708197030296,
#  'sexysasunday': -0.4163708197030296,
#  'scone': -0.7040528921548113,
#  'greec': -0.7040528921548113,
#  'motav': -0.7040528921548113,
#  'chanc': -1.3326615515771847,
#  'charcoal': -0.7040528921548113,
#  '2:30': -1.109518000262975,
#  'deck': -0.7040528921548113,
#  'necklac': -0.7040528921548113,
#  'ise': -0.7040528921548113,
#  'foot': -1.6203436240289655,
#  'follbaaack': 0.6822414689650795,
#  'schoolwork': -0.7040528921548113,
#  '18': -0.1650563914221248,
#  'worth': 1.1930670927310718,
#  'om': 0.6822414689650795,
#  'pandimension': 0.6822414689650795,
#  'shalwarkameez': 0.6822414689650795,
#  'pud': 0.6822414689650795,
#  'plant': 0.2767763608569158,
#  'doc': 0.6822414689650795,
#  'lemon': 1.087706577073245,
#  'eleph': 0.6822414689650795,
#  'smile': 1.5577102063189807,
#  'ramd': -0.7040528921548113,
#  'tseba': -0.7040528921548113,
#  'whammi': -0.7040528921548113,
#  'win': -0.624010184481274,
#  'hit': 1.0877065770732433,
#  'elgato': -0.7040528921548113,
#  'wah': 0.39455939651329963,
#  'und': 0.6822414689650795,
#  'stab': -1.3972000727147567,
#  'canva': 1.087706577073245,
#  'bencher': 0.6822414689650795,
#  'flippin': 0.6822414689650795,
#  'gue': -0.7040528921548113,
#  'aspetti': 0.6822414689650795,
#  'mom': -0.32935944271340034,
#  'apink': -1.3972000727147567,
#  'xx': 0.742866090781515,
#  'malik': -0.010905711594865863,
#  'scope': 1.7808537576331886,
#  'inni': 1.087706577073245,
#  'ehh': -0.7040528921548113,
#  'geneva': -0.7040528921548113,
#  'monteith': -0.7040528921548113,
#  'legendari': -0.7040528921548113,
#  'spanish': 0.39455939651329963,
#  'user': 0.6822414689650795,
#  'chwang': -0.7040528921548113,
#  'dunno': 0.6822414689650795,
#  'roadtrip': 0.6822414689650795,
#  'krystoria': -0.7040528921548113,
#  'fish': 0.4999199121711264,
#  'ann': -0.010905711594865863,
#  'hotscratch': -0.7040528921548113,
#  'bam': 3.7957567781754546,
#  '12th': -0.010905711594865863,
#  'na': -0.9759866076384522,
#  'fanart': 0.6822414689650795,
#  'hp': -1.109518000262975,
#  'fabfriday': 0.6822414689650795,
#  'marseil': 0.6822414689650795,
#  'bebe': -0.010905711594865863,
#  'graphic': 1.087706577073245,
#  'test': 0.12262568102965687,
#  '4am': -0.010905711594865863,
#  'eve': -0.7040528921548113,
#  'polit': -0.010905711594864087,
#  'regret': 0.21223783971934473,
#  'check-up': 0.6822414689650795,
#  'tearout': 0.6822414689650795,
#  'badass': 0.6822414689650795,
#  'avril': 0.6822414689650795,
#  'baggag': -1.109518000262975,
#  ';)': 3.1245885043342847,
#  'shortli': -0.010905711594865863,
#  'requir': -0.010905711594864087,
#  'slip': 0.6822414689650795,
#  'sum': -0.4163708197030296,
#  'razi': 1.087706577073245,
#  'updat': 0.15614837306830065,
#  'abhi': 1.087706577073245,
#  'barcelona': -0.7040528921548113,
#  'crei': -0.7040528921548113,
#  'bottl': -0.010905711594864087,
#  'arian': -0.7040528921548113,
#  "weekend'": 0.6822414689650795,
#  'pressreleas': 0.6822414689650795,
#  'litro': -0.7040528921548113,
#  'pre': -0.010905711594864087,
#  'knew': 0.2767763608569158,
#  'lynn': 0.6822414689650795,
#  'repackag': -0.7040528921548113,
#  'share': 1.529539329352283,
#  'open': -0.08501368374858664,
#  'comput': -0.19322726838881898,
#  'run': 0.07610566539476338,
#  'landscap': 1.087706577073245,
#  'consent': 0.6822414689650795,
#  'relax': -0.010905711594865863,
#  'bir': 0.6822414689650795,
#  'broadcast': -1.263668680090234,
#  'inaccess': 1.087706577073245,
#  'hospit': -0.29858778404664577,
#  'goodmorn': 2.0685358300849703,
#  'kikchat': -1.6203436240289655,
#  'pon': -0.7040528921548113,
#  "delevingne'": -0.7040528921548113,
#  'kid': -0.20506172603582318,
#  'owww': -0.4163708197030296,
#  'earth': 2.0685358300849703,
#  'yk': -0.7040528921548113,
#  'diff': -0.7040528921548113,
#  'itna': -1.109518000262975,
#  'kept': -1.109518000262975,
#  'chal': -0.7040528921548113,
#  'mixtap': -1.109518000262975,
#  'brother': -0.9271964434690201,
#  'orhan': 0.6822414689650795,
#  'discount': -0.7040528921548113,
#  'sadli': -1.8026651808229204,
#  'debbi': 0.6822414689650795,
#  'total': -0.3675806555335974,
#  'curv': -0.7040528921548113,
#  'haiss': -0.7040528921548113,
#  'bb17': -0.7040528921548113,
#  'rush': -0.4163708197030296,
#  'dream': -0.010905711594864975,
#  '2015kenya': 0.6822414689650795,
#  '✨': 0.9053850202792901,
#  'sunnyday': 0.6822414689650795,
#  'parisa': 0.6822414689650795,
#  '64': 0.6822414689650795,
#  'ding': -0.7040528921548113,
#  'cut': -1.551350752542013,
#  'loan': 1.087706577073245,
#  'actress': 0.6822414689650795,
#  'se100lead': 0.6822414689650795,
#  '24': -0.9271964434690201,
#  'dii': 0.6822414689650795,
#  'nighti': 0.6822414689650795,
#  'disney.art': 0.6822414689650795,
#  'iran': -0.7040528921548113,
#  'giveitup': 0.6822414689650795,
#  'bantim': 0.6822414689650795,
#  'rudramadevi': 0.6822414689650795,
#  '┻': 0.6822414689650795,
#  'tradit': -0.7040528921548113,
#  'remind': -0.010905711594864087,
#  'pun': 0.6822414689650795,
#  'sale': -0.8582035719820684,
#  'fade': 1.375388649525025,
#  'forgotten': -0.010905711594865863,
#  'suay': -0.7040528921548113,
#  'boreddd': -0.7040528921548113,
#  'expo': -1.109518000262975,
#  'overdrawn': -0.7040528921548113,
#  'need': -0.3336791038579161,
#  'saphir': 0.6822414689650795,
#  'incomplet': 0.6822414689650795,
#  'motn': -0.7040528921548113,
#  'leon': 0.6822414689650795,
#  'offshor': 0.6822414689650795,
#  'capee': -0.7040528921548113,
#  'wealth': 0.6822414689650795,
#  'theres': -0.7040528921548113,
#  'méxico': -0.010905711594865863,
#  'turkey': -0.010905711594865863,
#  '87': 0.6822414689650795,
#  'deantd': -0.7040528921548113,
#  'social': 0.9053850202792901,
#  "infinite'": -0.7040528921548113,
#  'pallavi': 0.6822414689650795,
#  'alhamdullilah': 0.6822414689650795,
#  'paysafecard': 0.6822414689650795,
#  'fittest': -0.7040528921548113,
#  'travel': 0.6822414689650804,
#  'tkt': 0.6822414689650795,
#  'addit': -0.7040528921548113,
#  'iyalaya': -0.7040528921548113,
#  'saaad': -1.3972000727147567,
#  'friend': 0.33929671783824933,
#  'sins': -0.7040528921548113,
#  'flaw': 0.6822414689650795,
#  'felton': -0.7040528921548113,
#  'syria': -1.109518000262975,
#  'x': 0.3374009826733504,
#  'valencia': 0.6822414689650795,
#  'barkkkiiidee': 0.6822414689650795,
#  'saw': 0.0497189102215696,
#  'bengali': -0.7040528921548113,
#  'larg': 1.375388649525025,
#  'cwnt': -0.7040528921548113,
#  ':|': 0.6822414689650795,
#  'merlin': -0.7040528921548113,
#  'next': 0.1609445453317946,
#  'grepe': -0.7040528921548113,
#  'asap': 0.6822414689650795,
#  'boggl': 0.6822414689650795,
#  'modifi': -0.7040528921548113,
#  'wear': -0.23404926290907468,
#  'flop': -0.7040528921548113,
#  '.\n.': -1.109518000262975,
#  'arch': -0.7040528921548113,
#  '2fm': -0.7040528921548113,
#  'se': 0.39455939651329963,
#  'air': 0.9699235414168612,
#  'lorenangel': 0.6822414689650795,
#  'england': 0.2767763608569158,
#  'afford': -2.090347253274702,
#  'xd': -0.5705214995302885,
#  'jazz': 1.087706577073245,
#  'pull': -0.010905711594865863,
#  'gud': 1.375388649525025,
#  'mixtur': -0.7040528921548113,
#  'bore': -0.8375842847793331,
#  '🎉': 0.9053850202792901,
#  'can': -0.7040528921548113,
#  'memem': -0.7040528921548113,
#  'arnd': 0.6822414689650795,
#  'ka': -0.010905711594864087,
#  'seriou': -0.7040528921548095,
#  'haaretz': -0.7040528921548113,
#  'cushion': 0.6822414689650795,
#  'lyric': -0.7040528921548113,
#  'inflat': -0.7040528921548113,
#  'boob': -0.4163708197030296,
#  'philippin': 1.087706577073245,
#  'anushka': 0.6822414689650795,
#  'hour': -0.08786675273099398,
#  'suitabl': 0.6822414689650795,
#  'foreal': -0.7040528921548113,
#  'foodiefriday': 0.6822414689650795,
#  'kebun': 0.6822414689650795,
#  'preciou': -1.3972000727147567,
#  'toe': -0.7040528921548113,
#  'cu': -0.7040528921548113,
#  'puhon': 0.6822414689650795,
#  'acheb': 0.6822414689650795,
#  'klappertart': -0.7040528921548113,
#  'mail': 1.375388649525025,
#  'nak': -0.7040528921548113,
#  'ncaaseason': 0.6822414689650795,
#  'bat': -0.010905711594865863,
#  'guin': -0.7040528921548113,
#  'bonilla': 1.375388649525025,
#  'cleans': 0.6822414689650795,
#  'orayt': 0.6822414689650795,
#  'plagu': -0.7040528921548113,
#  'robinhoodi': -0.7040528921548113,
#  'pre-holiday': -0.7040528921548113,
#  'eon': -0.7040528921548113,
#  'former': -0.7040528921548113,
#  'arc': 0.6822414689650795,
#  'web': 0.4999199121711264,
#  'odd': -0.010905711594864087,
#  'arini': -0.7040528921548113,
#  'ttctop': 0.6822414689650795,
#  'stocko': -0.7040528921548113,
#  'abit': 0.6822414689650795,
#  'secur': -0.29858778404664577,
#  'burn': -0.5217313353608546,
#  'agent': 0.6822414689650795,
#  'sjw': 0.6822414689650795,
#  'murugan': -0.7040528921548113,
#  'surrend': 1.087706577073245,
#  'differ': 0.0844044682094598,
#  'newest': 0.6822414689650795,
#  'cereal': -1.109518000262975,
#  'indiankultur': 0.6822414689650795,
#  'boom': 0.6822414689650795,
#  'cantik': 0.6822414689650795,
#  'whistl': -0.7040528921548113,
#  'jcreport': 0.6822414689650795,
#  'x27': 0.6822414689650795,
#  'drake': -0.7040528921548113,
#  'side': 0.6822414689650795,
#  'aggreg': 0.6822414689650795,
#  'content': 0.6822414689650795,
#  '07:32': -0.7040528921548113,
#  'nag.greet': 0.6822414689650795,
#  'atm': 1.5985322008392355,
#  'abuti': 0.6822414689650795,
#  'cutest': -0.4163708197030296,
#  'zayniscomingback': -1.3972000727147567,
#  '(:': -1.263668680090234,
#  'iirc': 0.6822414689650795,
#  'offboard': 0.6822414689650795,
#  'welder': -0.7040528921548113,
#  'que': -0.7040528921548113,
#  'shiatsu': -0.7040528921548113,
#  'feetblog': 1.087706577073245,
#  '100': -0.010905711594865863,
#  'icecreammast': 0.6822414689650795,
#  'bierc': 0.6822414689650795,
#  'warmest': -0.7040528921548113,
#  'orig': -0.7040528921548113,
#  'case': -0.1650563914221248,
#  'ofc': -0.010905711594865863,
#  'qt': -0.7040528921548113,
#  'wallet': -0.29858778404664577,
#  'qui': 0.6822414689650795,
#  'jaysu': -0.7040528921548113,
#  'persona': -0.010905711594865863,
#  'upsid': 0.6822414689650795,
#  '▪': 1.087706577073245,
#  'costacc': 0.6822414689650795,
#  'airdroid': -0.7040528921548113,
#  'retali': 0.6822414689650795,
#  'miracl': -0.7040528921548113,
#  'hash': 0.6822414689650795,
#  'dope': 1.087706577073245,
#  'legal': 0.6822414689650795,
#  'varsiti': -0.7040528921548113,
#  'vscophil': 0.6822414689650795,
#  'luv': 0.4999199121711264,
#  'lami': -0.7040528921548113,
#  'aldub': 0.39455939651329963,
#  'elmoprinssi': 0.6822414689650795,
#  'liter': -0.7040528921548104,
#  '─': 2.186318865741354,
#  'paperboy': 0.6822414689650795,
#  'deplet': -0.7040528921548113,
#  'panel': -0.7040528921548113,
#  'gensan': 0.6822414689650795,
#  'sour': -0.010905711594865863,
#  'taken': -1.3972000727147567,
#  'pinkeu': 0.6822414689650795,
#  'town': -1.109518000262975,
#  'sweetheart': 0.6822414689650795,
#  'maricarljanah': 0.6822414689650795,
#  'maxi': 0.6822414689650795,
#  'en': -0.010905711594865863,
#  'bike': 0.6822414689650795,
#  'hitler': 0.6822414689650795,
#  'wub': 0.6822414689650795,
#  'gagal': -1.109518000262975,
#  'old': -0.010905711594864975,
#  'orphan': -0.7040528921548113,
#  'nearer': -0.7040528921548113,
#  'therapi': -0.7040528921548113,
#  'pictur': -0.6395143710172393,
#  '132': 0.6822414689650795,
#  'fr': -0.010905711594865863,
#  '😚': -0.7040528921548113,
#  'yosh': 0.6822414689650795,
#  'howdo': -0.7040528921548113,
#  'nois': -0.29858778404664577,
#  'famili': 0.39455939651329963,
#  'buff': -0.7040528921548113,
#  'weddingflow': -0.7040528921548113,
#  'cloth': -1.109518000262975,
#  'dreamili': 0.6822414689650795,
#  'smashingbook': 0.6822414689650795,
#  'bish': -1.109518000262975,
#  'countthecost': -0.7040528921548113,
#  'hair': -0.7646775139712458,
#  'view': 0.6822414689650795,
#  'asham': -0.4163708197030296,
#  'phonesex': -0.010905711594865863,
#  '⅛': 0.6822414689650795,
#  'adf': 0.6822414689650795,
#  'haw': 0.6822414689650795,
#  'neh': -1.109518000262975,
#  'ke': -0.4163708197030296,
#  'bulat': 0.6822414689650795,
#  'melodi': 0.6822414689650795,
#  'luxurytravel': 0.6822414689650795,
#  'sad': -2.83426675920807,
#  'tito': -0.7040528921548113,
#  'chandauli': -0.7040528921548113,
#  'tam': -0.7040528921548113,
#  'quot': -0.010905711594865863,
#  'con-gradu': 0.6822414689650795,
#  'evil': -0.010905711594865863,
#  'shade': -0.7040528921548113,
#  'whatev': 1.5985322008392355,
#  'slice': 0.39455939651329963,
#  'youtub': 0.5768809533072545,
#  'numb': -0.7040528921548113,
#  'yna': -0.7040528921548113,
#  'foundat': -0.7040528921548113,
#  'easier': -0.29858778404664577,
#  'solut': -0.010905711594865863,
#  'lusi': -0.7040528921548113,
#  'gotten': 0.39455939651329963,
#  'beauti': 1.4198404120958585,
#  'comet': 0.6822414689650795,
#  '482': -0.7040528921548113,
#  '1,300': -0.7040528921548113,
#  'ju': 0.6822414689650795,
#  'spacer': 0.6822414689650795,
#  'baloch': 0.6822414689650795,
#  'wellington': 0.6822414689650795,
#  'imiss': -0.7040528921548113,
#  "what'": 0.05808715989208668,
#  '7/29': 0.6822414689650795,
#  'setter': -0.7040528921548113,
#  'donna': 0.6822414689650795,
#  '::': 1.5985322008392355,
#  'along': 0.39455939651329786,
#  'lovesummertim': 0.6822414689650795,
#  'triathlet': 0.6822414689650795,
#  'nage': -0.7040528921548113,
#  '20': -0.7040528921548113,
#  'et': -1.109518000262975,
#  'coz': -0.29858778404664577,
#  'dealsuthaonotebachao': 0.6822414689650795,
#  'jail': -1.109518000262975,
#  'soprano': 0.6822414689650795,
#  'mager': -0.7040528921548113,
#  'ux': 0.6822414689650795,
#  'nagato': 0.6822414689650795,
#  'pirouett': 0.6822414689650795,
#  "kareena'": 1.087706577073245,
#  '13glodyysbro': 0.6822414689650795,
#  'faaabul': 0.6822414689650795,
#  'iph': 1.087706577073245,
#  'bp': -0.010905711594865863,
#  'fanboy': 0.6822414689650795,
#  'innov': 0.6822414689650795,
#  'besteverdoctorwhoepisod': 0.6822414689650795,
#  'pyaari': -0.7040528921548113,
#  'incompleta': -0.7040528921548113,
#  'dragon': 1.087706577073245,
#  'buset': -0.7040528921548113,
#  'chelni': -0.5217313353608546,
#  'mistak': -0.8582035719820684,
#  '2suppli': -0.7040528921548113,
#  'fback': 3.2849311544094633,
#  'happier': -0.7040528921548113,
#  'jmu': -0.7040528921548113,
#  'cupboard': 0.6822414689650795,
#  'trip': 0.06913699607867141,
#  'syru': 0.6822414689650795,
#  'climb': -0.7040528921548113,
#  'sexual': -1.6203436240289655,
#  '2ne1': 0.6822414689650795,
#  'awesom': 1.7808537576331904,
#  '😊': -0.010905711594864087,
#  'bip': 0.6822414689650795,
#  'lafayett': -1.109518000262975,
#  '00962778381': 0.6822414689650795,
#  'giachietittiwed': -0.7040528921548113,
#  'gaya': 0.6822414689650795,
#  '15000': 0.6822414689650795,
#  'loftey': 0.6822414689650795,
#  'buynotanapologyonitun': -0.7040528921548113,
#  'stroke': 0.6822414689650795,
#  'mi': 0.4999199121711264,
#  'yeey': 0.6822414689650795,
#  'gene': -0.7040528921548113,
#  'still': -1.0272799020260024,
#  'yet': -0.879943558618475,
#  'clear': 0.6822414689650795,
#  'tato': 0.6822414689650795,
#  'miller': 0.6822414689650795,
#  '🍹': -1.3972000727147567,
#  'st': -0.7040528921548113,
#  'umaga': 0.6822414689650795,
#  'understand': -0.5499022123275523,
#  'llaollao': -0.7040528921548113,
#  'tattoo': 1.375388649525025,
#  'defin': 0.39455939651329963,
#  'fleur': 0.6822414689650795,
#  'happybirthday': 0.6822414689650795,
#  'dunwan': -0.7040528921548113,
#  'spent': -0.5217313353608546,
#  'note': 0.9053850202792901,
#  'm4': -0.7040528921548113,
#  'entrepreneurship': 0.6822414689650795,
#  're-watch': 0.6822414689650795,
#  'locat': -1.8026651808229204,
#  'net': -0.4163708197030296,
#  'windowsphon': -0.7040528921548113,
#  'entri': -0.010905711594865863,
#  'dard': -0.7040528921548113,
#  'victori': -0.7040528921548113,
#  'geek': 1.087706577073245,
#  'newslett': 0.6822414689650795,
#  'atl': 0.6822414689650795,
#  'grunt': 0.6822414689650795,
#  'pesaro': -0.7040528921548113,
#  'man': -0.3965681924068498,
#  'period': -0.7040528921548113,
#  'lootcrat': -0.7040528921548113,
#  'taray': -0.7040528921548113,
#  'dongwoo': -0.7040528921548113,
#  'sofa': 0.6822414689650795,
#  'cintiq': -0.7040528921548113,
#  'bland': -0.7040528921548113,
#  'notif': -0.010905711594864087,
#  ":'(": -2.575855069056402,
#  'sue': -0.7040528921548113,
#  'earl': 0.6822414689650795,
#  'sobtian': 0.6822414689650795,
#  'soulmat': -0.7040528921548113,
#  'techniqu': -0.7040528921548113,
#  '11:15': -0.7040528921548113,
#  'subtitl': -0.7040528921548113,
#  'possitv': 0.6822414689650795,
#  'includ': 0.6822414689650795,
#  'takeov': -0.7040528921548113,
#  '∞': 0.6822414689650795,
#  'dorm': -0.7040528921548113,
#  'petal': -0.7040528921548113,
#  'vantast': 0.6822414689650795,
#  'kahlil': 0.6822414689650795,
#  'puddl': -1.109518000262975,
#  'flash': -0.010905711594865863,
#  'ohmygod': -0.7040528921548113,
#  'august': -0.010905711594865863,
#  'cousin': -0.010905711594865863,
#  'ff__special': 0.6822414689650795,
#  'boxroomcraft': 0.6822414689650795,
#  'myhil': -0.7040528921548113,
#  'heechul': 0.6822414689650795,
#  'vodka': 0.6822414689650795,
#  'rlyyi': -0.7040528921548113,
#  'fire': -0.010905711594865863,
#  'ki': -0.4163708197030296,
#  'wider': -0.7040528921548113,
#  'jsl': 0.6822414689650795,
#  'promethazin': -0.7040528921548113,
#  'mosqu': -0.7040528921548113,
#  'sarah': 1.5985322008392355,
#  'mam-bulli': -0.7040528921548113,
#  'bill': -0.19322726838881898,
#  'heiya': 1.087706577073245,
#  'chel': -0.7040528921548113,
#  'glow': -0.010905711594865863,
#  'chilton': -0.7040528921548113,
#  "they'r": -0.25206776841175316,
#  'when': -1.109518000262975,
#  'bigtim': -0.7040528921548113,
#  'imper': -0.7040528921548113,
#  'gamedev': 0.6822414689650795,
#  'dancee': -0.7040528921548113,
#  'heavi': -0.29858778404664577,
#  'x46': 0.6822414689650795,
#  'zonzofox': 1.087706577073245,
#  'one': -0.2574297115531383,
#  'inshallah': 0.6822414689650795,
#  'distribut': 0.6822414689650795,
#  '=:': 1.087706577073245,
#  'toddlerlif': 0.6822414689650795,
#  "ray'": 0.6822414689650795,
#  'naaahhh': 0.6822414689650795,
#  'unfriend': -0.7040528921548113,
#  'hot': 0.7310316331345126,
#  '7am': -0.010905711594865863,
#  'stalk': -0.29858778404664577,
#  'clutch': -0.010905711594865863,
#  'brandi': 0.6822414689650795,
#  'pepsi': 0.6822414689650795,
#  'ill': -0.5499022123275523,
#  'novel': 0.6822414689650795,
#  '👓': 0.6822414689650795,
#  'judi': 0.6822414689650795,
#  'blurri': 0.6822414689650795,
#  'employ': 1.7808537576331886,
#  'fashion': 1.087706577073245,
#  'path': -0.010905711594865863,
#  'mne': 0.6822414689650795,
#  'other': 0.2404087166860407,
#  'crown': -0.7040528921548113,
#  'mischiev': 0.6822414689650795,
#  '330': -0.7040528921548113,
#  'alison': 0.6822414689650795,
#  '8.40': -0.7040528921548113,
#  'arma': 0.6822414689650795,
#  'josh': -0.010905711594865863,
#  'reput': 1.087706577073245,
#  'orchestra': -0.7040528921548113,
#  'faith': 0.6822414689650795,
#  'took': -0.010905711594865863,
#  'sock': -1.6203436240289655,
#  'kate': -1.109518000262975,
#  'nai': -0.7040528921548113,
#  'bad': -1.3101886957251256,
#  'jump': -0.29858778404664577,
#  'thumb': 0.6822414689650795,
#  'heathrow': -0.7040528921548113,
#  'bale': -0.7040528921548113,
#  'makati': -0.7040528921548113,
#  'deennya': 0.6822414689650795,
#  'messeng': -0.7040528921548113,
#  'coyot': -0.7040528921548113,
#  'vam': -0.7040528921548113,
#  'relev': 0.6822414689650795,
#  'spag': 0.6822414689650795,
#  'leicaq': 0.6822414689650795,
#  'apart': -0.9917349646065912,
#  'pokemon': 0.6822414689650795,
#  'ride': 0.6822414689650795,
#  'newyork': 0.6822414689650795,
#  'thursday': 0.39455939651329963,
#  'gottolovebank': 0.6822414689650795,
#  'lu': -0.010905711594865863,
#  'marino': -0.7040528921548113,
#  'averag': 0.6822414689650795,
#  'cajunchicken': 0.6822414689650795,
#  'repack': -1.3972000727147567,
#  'karibumombasa': 0.6822414689650795,
#  'broker': -0.7040528921548113,
#  'hopeless': -1.109518000262975,
#  'alberta': -0.7040528921548113,
#  'thegrandad': 0.6822414689650795,
#  'yell': -0.010905711594864087,
#  'laribuggi': -0.7040528921548113,
#  'help': -0.10399613466087754,
#  'million': 1.087706577073245,
#  'accur': -0.4163708197030296,
#  'lew': -0.7040528921548113,
#  'legsupthewal': 0.6822414689650795,
#  "s'okay": 0.6822414689650795,
#  'sheep': -0.010905711594865863,
#  'wingstop': -0.7040528921548113,
#  'immigr': 0.6822414689650795,
#  'gidi': -0.7040528921548113,
#  'hunt': 0.6822414689650795,
#  'reserv': 1.375388649525025,
#  'gel': 0.6822414689650795,
#  'happycustom': 0.6822414689650795,
#  'tommi': -0.7040528921548113,
#  'pitmantrain': 0.6822414689650795,
#  'cam': 1.375388649525025,
#  'iwantin': -0.7040528921548113,
#  'sucki': -0.7040528921548113,
#  'standard': 1.087706577073245,
#  'cart': -0.7040528921548113,
#  'in-app': 0.6822414689650795,
#  'kaussi': -0.7040528921548113,
#  'peso': -0.7040528921548113,
#  'protect': -0.010905711594865863,
#  'routt': 0.6822414689650795,
#  'ako': -0.010905711594865863,
#  'dearli': -0.7040528921548113,
#  'forest': -0.010905711594865863,
#  'kleper': 0.6822414689650795,
#  'mork': -0.7040528921548113,
#  'michel': 0.6822414689650795,
#  'portrait': -0.010905711594865863,
#  'closer-chas': 0.6822414689650795,
#  'consult': 0.6822414689650795,
#  'cold': -1.9568158606501784,
#  'tnc': 0.6822414689650795,
#  'bruis': -0.010905711594865863,
#  'goodafternoon': 0.39455939651329963,
#  'crypt': 0.6822414689650795,
#  'thoughtseiz': -0.7040528921548113,
#  'pausetim': 0.6822414689650795,
#  'utd': -0.7040528921548113,
#  'punt': 0.6822414689650795,
#  'niec': -0.7040528921548113,
#  '2015': 0.14324496823239308,
#  ...}

# %% [markdown]
# in the probability above, if the value is positive then it is a positive word.
# and if the value is negative, then it is a negative word

# %% [markdown]
# ok lets predict some tweet using Naive Bayes Logarithm

# %%
def predict_tweet(tweet, logprior, loglikelihood):

    # PREPROCESS TEXT
    cleaned_tweet = tokenizer(tweet)

    probability = 0  # TO STORE PROBABILTY OF TWEET BEING POSITIVE OR NEGATIVE

    probability += logprior  # ADD LOGPRIOR TO PROBABILITY

    for word in cleaned_tweet:
        probability += loglikelihood.get(word, 0)

    return probability

# %%
# FUNCTION TO CONVER RAW VALUES TO LABELS (POSITIVE OR NEGATIVE)
def isPositive(numeric):
    if numeric >= 0:
        return 'Positive'
    else:
        return 'Negative'

# %%
# PREDICT SOME TWEET

word_1 = 'I hate you guys'
word_2 = "Just wanna let this story die and i'll be alright"
word_3 = 'Die with a Smile'
word_4 = 'Thank you for your helping :)'

probs_1 = predict_tweet(word_1, logprior, loglikelihood)
probs_2 = predict_tweet(word_2,logprior, loglikelihood)
probs_3 = predict_tweet(word_3,logprior, loglikelihood)
probs_4 = predict_tweet(word_4,logprior, loglikelihood)

print(f' {word_1} --> {isPositive(probs_1)}')
print(f' {word_2} --> {isPositive(probs_2)}')
print(f' {word_3} --> {isPositive(probs_3)}')
print(f' {word_4} --> {isPositive(probs_4)}')
# Out:
#  I hate you guys --> Negative
#  Just wanna let this story die and i'll be alright --> Negative
#  Die with a Smile --> Positive
#  Thank you for your helping :) --> Positive

# %% [markdown]
# now lets test our model accuracy

# %%
# TEST MODEL

def test_model(data, label, logprior, loglikelihood):

    # DECLARE SOME VARIABLE
    accuracy = 0  
    y_preds = []

    # ITERATE EVERY TWEET IN DATASET
    for tweet in data:

        # SET PROBABILITY FOR EACH TWEET
        probability = predict_tweet(tweet, logprior, loglikelihood)

        # IF PROBS MORE THAN 0 THEN ITS CATEGORIZED AS POSITIVE WORD , OTHERWISE NEGATIVE.
        if probability > 0:
            y_pred_i = 1
        else:
            y_pred_i = 0

        y_preds.append(y_pred_i)
        
    # COMPUTE LOSS FUNCTION
    loss_function = sum(abs(y_hat - y) for y_hat, y in zip(y_preds, label)) / len(label)

    accuracy = 1 - loss_function
    
    return loss_function, accuracy

# %%
loss_function , accuracy = test_model(test_data, test_label, logprior, loglikelihood)

accuracy , loss_function
# Out:
# (array([0.9955]), array([0.0045]))

# %% [markdown]
# show positive and negative ratio for each word

# %% [markdown]
# ## Ratio Word

# %%
def get_ratio(word, frequency_token):

    # CREATE RATIO DICTIONARY
    ratio = {'positive': 0,
             'negative': 0,
             'ratio'   : 0.0}
    
    ratio['positive'] = frequency_token[(word, 1)]
    ratio['negative'] = frequency_token[(word, 0)]

    # CALCULATE THE RATIO OF POSITIVE TO NEGATIVE VALUE
    ratio['ratio']    = (ratio['positive'] + 1) / (ratio['negative'] + 1)  # ADD 1 TO AVOID DIVISION BY ZERO
    return ratio

# %%
# DISPLAY RESULT

words = ['hi','love','happi','smell','smile','die']

for word in words:
    ratio = get_ratio(word, frequency_token)
    
    print(f'word : {word} --> positive : {ratio["positive"]} , negative : {ratio["negative"]} , ratio : {ratio["ratio"]}')
    print()
# Out:
# word : hi --> positive : 154 , negative : 28 , ratio : 5.344827586206897
#
# word : love --> positive : 336 , negative : 128 , ratio : 2.612403100775194
#
# word : happi --> positive : 162 , negative : 18 , ratio : 8.578947368421053
#
# word : smell --> positive : 2 , negative : 2 , ratio : 1.0
#
# word : smile --> positive : 47 , negative : 9 , ratio : 4.8
#
# word : die --> positive : 8 , negative : 15 , ratio : 0.5625
